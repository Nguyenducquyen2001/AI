# %%
from keras.datasets import boston_housing
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()
from sklearn.preprocessing import  StandardScaler
from keras.optimizers import Adam
sc = StandardScaler()
sc.fit(x_train)
sc.fit(x_test)
x_train = sc.transform(x_train)
x_test = sc.transform(x_test)
from keras import models
from keras.layers import Dense

from keras.models import Sequential

# model = Sequential()
# model.add(Dense(512, activation='relu', input_shape=(13,), name='Lop1'))
# model.add(Dense(512, activation='relu', input_shape=(13,), name='Lop2'))
# model.add(Dense(512, activation='relu', input_shape=(13,), name='Lop3'))
# model.add(Dense(1, activation='linear', name='LopRa'))
model= Sequential([
    Dense(512, activation='relu', input_shape=(13,), name='Lop1'),
    Dense(256, activation='relu', input_shape=(13,), name='Lop2'),
    Dense(128, activation='relu', input_shape=(13,), name='Lop3'),
    Dense(3, activation='linear', name='LopRa')
])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Lop1 (Dense)                (None, 512)               7168
#
#  Lop2 (Dense)                (None, 256)               131328
#
#  Lop3 (Dense)                (None, 128)               32896
#
#  LopRa (Dense)               (None, 3)                 387
#
# ...
# Total params: 171,779
# Trainable params: 171,779
# Non-trainable params: 0
# _________________________________________________________________
# None
