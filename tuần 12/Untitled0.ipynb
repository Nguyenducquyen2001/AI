# %%
 pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 29.4 MB/s eta 0:00:00
# ...

# %%
pip install facenet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 63.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
from  mtcnn import MTCNN
filename ='/content/drive/MyDrive/anh/anh_lopC.jpg'
img = plt.imread(filename)
plt.imshow(img)
detector=MTCNN()
faces=detector.detect_faces(img)
for face in faces :
   print(face)
# Out:
# ...
# 3/3 [==============================] - 0s 24ms/step
# {'box': [170, 461, 50, 55], 'confidence': 0.9999944567680359, 'keypoints': {'left_eye': (185, 483), 'right_eye': (209, 481), 'nose': (197, 494), 'mouth_left': (187, 502), 'mouth_right': (207, 501)}}
# {'box': [653, 397, 31, 40], 'confidence': 0.9997849464416504, 'keypoints': {'left_eye': (661, 413), 'right_eye': (676, 413), 'nose': (668, 421), 'mouth_left': (663, 429), 'mouth_right': (673, 428)}}
# {'box': [311, 273, 36, 42], 'confidence': 0.9996545314788818, 'keypoints': {'left_eye': (322, 288), 'right_eye': (338, 287), 'nose': (331, 295), 'mouth_left': (324, 305), 'mouth_right': (337, 304)}}
# {'box': [126, 285, 46, 52], 'confidence': 0.9994967579841614, 'keypoints': {'left_eye': (140, 304), 'right_eye': (161, 303), 'nose': (152, 314), 'mouth_left': (142, 323), 'mouth_right': (158, 323)}}
# ...

# %%
import matplotlib.pyplot as plt
from  mtcnn import MTCNN
filename ='/content/drive/MyDrive/anh/anh test.jpg'
img = plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(img)
for face in faces :
   print(face)
plt.imshow(img)
ax=plt.gca()
for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
  plt.axis('off')
  # plt.savefig(/content/drive/MyDrive/anh/anh test.jpg)
plt.show()
# Out:
# ...
# 9/9 [==============================] - 1s 56ms/step
# {'box': [61, 173, 33, 44], 'confidence': 0.9999989867210388, 'keypoints': {'left_eye': (74, 190), 'right_eye': (89, 191), 'nose': (85, 199), 'mouth_left': (76, 208), 'mouth_right': (87, 208)}}
# {'box': [186, 47, 29, 33], 'confidence': 0.9999988675117493, 'keypoints': {'left_eye': (193, 61), 'right_eye': (206, 58), 'nose': (198, 65), 'mouth_left': (196, 75), 'mouth_right': (206, 72)}}
# {'box': [580, 341, 48, 57], 'confidence': 0.9999973177909851, 'keypoints': {'left_eye': (610, 361), 'right_eye': (627, 362), 'nose': (625, 378), 'mouth_left': (608, 388), 'mouth_right': (621, 389)}}
# {'box': [525, 36, 30, 35], 'confidence': 0.9999920725822449, 'keypoints': {'left_eye': (535, 49), 'right_eye': (549, 50), 'nose': (542, 57), 'mouth_left': (535, 63), 'mouth_right': (547, 64)}}
# ...

# %%
import matplotlib.pyplot as plt
from  mtcnn import MTCNN
filename ='/content/drive/MyDrive/anh/khau_trang.jpg'
img = plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(img)
for face in faces :
   print(face)
plt.imshow(img)
ax=plt.gca()
for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
  plt.axis('off')
  for key,value in face['keypoints'].items():
    dot=plt.Circle(value,radius=2,color='red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 8/8 [==============================] - 1s 51ms/step
# {'box': [732, 430, 42, 50], 'confidence': 0.9999819397926331, 'keypoints': {'left_eye': (742, 451), 'right_eye': (762, 451), 'nose': (749, 460), 'mouth_left': (741, 470), 'mouth_right': (758, 472)}}
# {'box': [971, 416, 39, 51], 'confidence': 0.9999694228172302, 'keypoints': {'left_eye': (983, 436), 'right_eye': (1002, 437), 'nose': (993, 446), 'mouth_left': (984, 456), 'mouth_right': (999, 456)}}
# {'box': [129, 458, 50, 58], 'confidence': 0.999945342540741, 'keypoints': {'left_eye': (139, 482), 'right_eye': (159, 481), 'nose': (143, 495), 'mouth_left': (138, 504), 'mouth_right': (156, 502)}}
# {'box': [62, 447, 61, 69], 'confidence': 0.9999396204948425, 'keypoints': {'left_eye': (76, 477), 'right_eye': (102, 476), 'nose': (86, 493), 'mouth_left': (79, 503), 'mouth_right': (99, 503)}}
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

def draw_faces(filename,result_list):
  data=plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height=result_list[i]['box']
    x2,y2=x1+width,y1+height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
    # plt.save('/content/drive/MyDrive/anh')
  plt.show()
filename ='/content/drive/MyDrive/anh/khau_trang.jpg'
img = plt.imread(filename)
detector=MTCNN()
faces=detector.detect_faces(img)
draw_faces(filename,faces)
# save('/content/drive/MyDrive/anh/hoa/hoa_photos.npy')
# Out:
# ...
# 8/8 [==============================] - 0s 35ms/step

# %%
import tensorflow
from keras.utils.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/drive/MyDrive/anh/images.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-45-2a16e8b6f3a9> in <cell line: 2>()
#       1 import tensorflow
# ----> 2 from keras.utils.resnet50 import ResNet50
#       3 from tensorflow.keras.preprocessing import image
#       4 from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'keras.utils.resnet50'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
